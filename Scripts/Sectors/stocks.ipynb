# %%
from openbb_terminal.sdk import openbb
from datetime import datetime
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go
# %matplotlib inline
# Out:
# /Users/mark/opt/anaconda3/envs/obb/lib/python3.9/site-packages/openbb_terminal/stocks/options/tmx_model.py:51: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   options_listings = pd.read_html(r.text)
# Forecasting Toolkit is disabled. To use the Forecasting features please install the toolkit following the instructions here: https://my.openbb.co/app/sdk/installation
# Portfolio Optimization Toolkit is disabled. To use the Optimization features please install the toolkit following the instructions here: https://my.openbb.co/app/sdk/installation

# %%
reli = openbb.stocks.load(
    symbol = 'LTMAQ',
    interval = 1440,
    prepost = False,
    source = 'YahooFinance',
    weekly = False,
    monthly = True,
)

# reli['daily_rtn'] = reli['Adj Close'].pct_change()
reli
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
openbb.stocks.candle(data=reli, symbol='LTMAQ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 openbb.stocks.candle(data=reli, symbol='LTMAQ')
#
# File ~/opt/anaconda3/envs/obb/lib/python3.9/site-packages/openbb_terminal/core/sdk/sdk_helpers.py:107, in Operation.__call__(self, *args, **kwargs)
#     101 operation_logger = OperationLogger(
#     102     trail=self._trail, method_chosen=method, args=args, kwargs=log_kwargs
#     103 )
#     105 operation_logger.log_before_call()
# --> 107 method_result = method(*args, **kwargs)
#     109 operation_logger.log_after_call(method_result=method_result)
#     111 return method_result
#
# File ~/opt/anaconda3/envs/obb/lib/python3.9/site-packages/openbb_terminal/stocks/stocks_helper.py:664, in display_candle(symbol, data, add_trend, ma, asset_type, start_date, interval, end_date, prepost, source, weekly, monthly, ha, external_axes, raw, yscale)
#     653 if data is None or data.empty:
#     654     data = load(
#     655         symbol,
#     656         start_date,
#    (...)
#     662         monthly,
#     663     )
# --> 664     data = process_candle(data)
#     666 if add_trend and (data.index[1] - data.index[0]).total_seconds() >= 86400:
#     667     data = find_trendline(data, "OC_High", "high")
#
# File ~/opt/anaconda3/envs/obb/lib/python3.9/site-packages/openbb_terminal/stocks/stocks_helper.py:715, in process_candle(data)
#     701 """Process DataFrame into candle style plot.
#     702
#     703 Parameters
#    (...)
#     712     date_id, OC-High, OC-Low.
#     713 """
#     714 df_data = data.copy()
# --> 715 df_data["date_id"] = (df_data.index.date - df_data.index.date.min()).astype(
#     716     "timedelta64[D]"
#     717 )
#     718 df_data["date_id"] = df_data["date_id"].dt.days + 1
#     720 df_data["OC_High"] = df_data[["Open", "Close"]].max(axis=1)
#
# AttributeError: 'RangeIndex' object has no attribute 'date'

# %%
openbb.stocks.candle('MARA', ma=[30,90])
# Out:
# Loading Daily data for MARA with starting period 2020-11-03.

# %%
openbb.stocks.search(query='PCAR')
# Out:
#                                            Companies found on term PCAR
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ Symbol ┃ name               ┃ country       ┃ sector      ┃ industry group     ┃ industry            ┃ exchange ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━┩
# │ EURMF  │ Europcar Mobility  │ France        │ Industrials │ Commercial &       │ Commercial Services │ PNK      │
# │        │ Group S.A.         │               │             │ Professional       │ & Supplies          │          │
# │        │                    │               │             │ Services           │                     │          │
# ├────────┼────────────────────┼───────────────┼─────────────┼────────────────────┼─────────────────────┼──────────┤
# │ PCAR   │ PACCAR Inc         │ United States │ Industrials │ Capital Goods      │ Machinery           │ NMS      │
# └────────┴────────────────────┴───────────────┴─────────────┴────────────────────┴─────────────────────┴──────────┘
#                                 name        country       sector  \
# symbol
# EURMF   Europcar Mobility Group S.A.         France  Industrials
# PCAR                      PACCAR Inc  United States  Industrials
#
#                             industry_group                        industry  \
# symbol
# EURMF   Commercial & Professional Services  Commercial Services & Supplies
# PCAR                         Capital Goods                       Machinery
#
#        exchange
# symbol
# EURMF       PNK
# PCAR        NMS

# %%
stocktwits = openbb.stocks.ba.trending()
stocktwits = pd.DataFrame(stocktwits).sort_values(by = 'Watchlist Count', ascending = False)
tickers = stocktwits['Ticker'].to_list()
stocktwits
# Out:
#     Ticker  Watchlist Count                                               Name
# 6     NVDA           448379                                        NVIDIA Corp
# 0      DIS           278320                                    Walt Disney Co.
# 17    MARA           127094                      Marathon Digital Holdings Inc
# 15    RIOT           114793                                Riot Blockchain Inc
# 2     WISH            70379       ContextLogic Inc - Ordinary Shares - Class A
# 20    RIVN            65735                              Rivian Automotive Inc
# 7     RBLX            61927                                 ROBLOX CORPORATION
# 8     HOOD            54428                              Robinhood Markets Inc
# 10    TWLO            45364                                         Twilio Inc
# 12    UPST            39567                               Upstart Holdings Inc
# 18    AFRM            32973                                Affirm Holdings Inc
# 4   LINK.X            31108                                          ChainLink
# 19    GOLD            26624                                 Barrick Gold Corp.
# 5     SAVE            24671                                Spirit Airlines Inc
# 9     UWMC            22791  UWM Holdings Corporation - Ordinary Shares - C...
# 25     BBY            17288                                  Best Buy Co. Inc.
# 1      LLY            14087                                    Lilly(Eli) & Co
# 26      BE            13943                                  Bloom Energy Corp
# 21     NEM             9105                                       Newmont Corp
# 13     WBD             6066                          Warner Bros.Discovery Inc
# 14    CANO             5944        Cano Health Inc - Ordinary Shares - Class A
# 24      GH             4201                                Guardant Health Inc
# 22      MQ             4023                                        Marqeta Inc
# 23    ALEC             1610                                        Alector Inc
# 16   GAS.X             1165                                                Gas
# 27    SIVR              938       abrdn ETF - abrdn Physical Silver Shares ETF
# 28    SGOL              732         abrdn ETF - abrdn Physical Gold Shares ETF
# 29    EWBC              431                            East West Bancorp, Inc.
# 3     RMCO              358                    Royalty Management Holding Corp
# 11    ESTA              326                    Establishment Labs Holdings Inc

# %%
screener_results = openbb.stocks.ca.screener(similar = tickers, data_type = 'overview')
# screener_results = screener_results.sort_values(by = ['Market Cap'], ascending = False)

screener_results
# Out:
# Invalid data from website
# Empty DataFrame
# Columns: []
# Index: []

# %%
openbb.stocks.ca.income(similar = ['AAPL', 'AMZN', 'TSLA'], quarter = True)
# Out:
# Other available quarterly timeframes are: 30-Jun-2022, 30-Sep-2022, 31-Dec-2022, 31-Mar-2023, 30-Jun-2023
#                                           AAPL (30-Jun-2023)  \
# Item
# Sales/Revenue                                          81.8B
# Sales Growth                                         -13.75%
# Cost of Goods Sold (COGS) incl. D&A                   45.38B
# COGS Growth                                          -14.14%
# COGS excluding D&A                                    42.33B
# Depreciation & Amortization Expense                    3.05B
# Depreciation                                           3.05B
# Amortization of Intangibles
# Gross Income                                          36.41B
# Gross Income Growth                                  -13.25%
# Gross Profit Margin                                   44.52%
# SG&A Expense                                          13.42B
# SGA Growth                                            -1.78%
# Research & Development                                 7.44B
# Other SG&A                                             5.97B
# Other Operating Expense
# Unusual Expense
# EBIT after Unusual Expense
# Non Operating Income/Expense                          (247M)
# Non-Operating Interest Income                           980M
# Equity in Affiliates (Pretax)
# Interest Expense                                        998M
# Interest Expense Growth                                7.31%
# Gross Interest Expense                                  998M
# Interest Capitalized
# Pretax Income                                         22.73B
# Pretax Income Growth                                 -19.90%
# Pretax Margin                                         27.79%
# Income Tax                                             2.85B
# Income Tax - Current Domestic
# Income Tax - Current Foreign
# Income Tax - Deferred Domestic
# Income Tax - Deferred Foreign
# Income Tax Credits
# Equity in Affiliates
# Other After Tax Income (Expense)
# Consolidated Net Income                               19.88B
# Minority Interest Expense
# Net Income                                            19.88B
# Net Income Growth                                    -17.71%
# Net Margin Growth                                     24.31%
# Extraordinaries & Discontinued Operations
# Extra Items & Gain/Loss Sale Of Assets
# Cumulative Effect - Accounting Chg
# Discontinued Operations
# Net Income After Extraordinaries                      19.88B
# Preferred Dividends
# Net Income Available to Common                        19.88B
# EPS (Basic)                                             1.27
# EPS (Basic) Growth                                   -17.24%
# Basic Shares Outstanding                               15.7B
# EPS (Diluted)                                           1.26
# EPS (Diluted) Growth                                 -17.34%
# Diluted Shares Outstanding                            15.78B
# EBITDA                                                26.05B
# EBITDA Growth                                        -16.55%
# EBITDA Margin                                         31.85%
#
#                                           AMZN (30-Jun-2023)  \
# Item
# Sales/Revenue                                        134.38B
# Sales Growth                                           5.52%
# Cost of Goods Sold (COGS) incl. D&A                   69.37B
# COGS Growth                                            2.33%
# COGS excluding D&A                                    57.78B
# Depreciation & Amortization Expense                   11.59B
# Depreciation
# Amortization of Intangibles
# Gross Income                                          65.01B
# Gross Income Growth                                    9.14%
# Gross Profit Margin                                   48.38%
# SG&A Expense                                          57.18B
# SGA Growth                                             4.79%
# Research & Development                                21.93B
# Other SG&A                                            35.25B
# Other Operating Expense
# Unusual Expense                                         (9M)
# EBIT after Unusual Expense                                9M
# Non Operating Income/Expense                           (94M)
# Non-Operating Interest Income                           661M
# Equity in Affiliates (Pretax)
# Interest Expense                                        840M
# Interest Expense Growth                                2.07%
# Gross Interest Expense                                  840M
# Interest Capitalized
# Pretax Income                                          7.56B
# Pretax Income Growth                                  83.61%
# Pretax Margin                                          5.63%
# Income Tax                                              804M
# Income Tax - Current Domestic
# Income Tax - Current Foreign
# Income Tax - Deferred Domestic
# Income Tax - Deferred Foreign
# Income Tax Credits
# Equity in Affiliates                                    (9M)
# Other After Tax Income (Expense)
# Consolidated Net Income                                6.75B
# Minority Interest Expense
# Net Income                                             6.75B
# Net Income Growth                                    112.80%
# Net Margin Growth                                      5.02%
# Extraordinaries & Discontinued Operations
# Extra Items & Gain/Loss Sale Of Assets
# Cumulative Effect - Accounting Chg
# Discontinued Operations
# Net Income After Extraordinaries                       6.75B
# Preferred Dividends
# Net Income Available to Common                         6.75B
# EPS (Basic)                                             0.66
# EPS (Basic) Growth                                   112.05%
# Basic Shares Outstanding                              10.29B
# EPS (Diluted)                                           0.65
# EPS (Diluted) Growth                                 110.70%
# Diluted Shares Outstanding                            10.45B
# EBITDA                                                19.42B
# EBITDA Growth                                         20.45%
# EBITDA Margin                                         14.45%
#
#                                           TSLA (30-Jun-2023)
# Item
# Sales/Revenue                                         24.93B
# Sales Growth                                           6.85%
# Cost of Goods Sold (COGS) incl. D&A                   20.39B
# COGS Growth                                            8.37%
# COGS excluding D&A                                    19.24B
# Depreciation & Amortization Expense                    1.15B
# Depreciation                                            816M
# Amortization of Intangibles                             338M
# Gross Income                                           4.53B
# Gross Income Growth                                    0.49%
# Gross Profit Margin                                   18.19%
# SG&A Expense                                           2.13B
# SGA Growth                                            15.54%
# Research & Development                                  943M
# Other SG&A                                             1.19B
# Other Operating Expense
# Unusual Expense                                         (2M)
# EBIT after Unusual Expense                                2M
# Non Operating Income/Expense                            326M
# Non-Operating Interest Income                           238M
# Equity in Affiliates (Pretax)
# Interest Expense                                         28M
# Interest Expense Growth                               -3.45%
# Gross Interest Expense                                   28M
# Interest Capitalized
# Pretax Income                                          2.94B
# Pretax Income Growth                                   4.89%
# Pretax Margin                                         11.78%
# Income Tax                                              323M
# Income Tax - Current Domestic
# Income Tax - Current Foreign
# Income Tax - Deferred Domestic
# Income Tax - Deferred Foreign
# Income Tax Credits
# Equity in Affiliates
# Other After Tax Income (Expense)
# Consolidated Net Income                                2.61B
# Minority Interest Expense                              (89M)
# Net Income                                              2.7B
# Net Income Growth                                      7.35%
# Net Margin Growth                                     10.84%
# Extraordinaries & Discontinued Operations
# Extra Items & Gain/Loss Sale Of Assets
# Cumulative Effect - Accounting Chg
# Discontinued Operations
# Net Income After Extraordinaries                        2.7B
# Preferred Dividends
# Net Income Available to Common                          2.7B
# EPS (Basic)                                             0.85
# EPS (Basic) Growth                                     7.18%
# Basic Shares Outstanding                               3.17B
# EPS (Diluted)                                           0.78
# EPS (Diluted) Growth                                   7.04%
# Diluted Shares Outstanding                             3.48B
# EBITDA                                                 3.55B
# EBITDA Growth                                         -4.23%
# EBITDA Margin                                         14.25%

# %%
openbb.stocks.fa.ratios(symbol = 'AAPL')
# Out:
# Fiscal Date Ending                              2022       2021       2020  \
# Period                                            FY         FY         FY
# Current ratio                               0.879356   1.074553   1.363604
# Quick ratio                                 0.709408    0.90966   1.218195
# Cash ratio                                  0.153563   0.278449    0.36071
# Days of sales outstanding                  56.400205  51.390969  49.787534
# Days of inventory outstanding               8.075698  11.276593   8.741883
# Operating cycle                            64.475903  62.667561  58.529418
# Days of payables outstanding              104.685277  93.851071   91.04819
# Cash conversion cycle                     -40.209374  -31.18351 -32.518772
# Gross profit margin                         0.433096   0.417794   0.382332
# Operating profit margin                     0.302887   0.297824   0.241473
# Pretax profit margin                         0.30204   0.298529   0.244398
# Net profit margin                           0.253096   0.258818   0.209136
# Effective tax rate                          0.162045   0.133023   0.144282
# Return on assets                            0.282924   0.269742   0.177256
# Return on equity                            1.969589   1.500713   0.878664
# Return on capital employed                  0.600871   0.483099   0.303383
# Net income per EBT                          0.837955   0.866977   0.855718
# Ebt per ebit                                0.997204   1.002368   1.012114
# Ebit per revenue                            0.302887   0.297824   0.241473
# Debt ratio                                  0.340375   0.355323   0.347145
# Debt equity ratio                           2.369533   1.976843    1.72081
# Long term debt to capitalization            0.661354   0.633615   0.601606
# Total debt to capitalization                0.703223   0.664074   0.632462
# Interest coverage                          40.749574  41.190548  23.072746
# Cash flow to debt ratio                      1.01734   0.834179    0.71751
# Company equity multiplier                   6.961537   5.563512   4.957039
# Receivables turnover                        6.471608   7.102415   7.331152
# Payables turnover                           3.486641    3.88914   4.008866
# Inventory turnover                         45.197331  32.367933  41.753016
# Fixed asset turnover                         9.36268   9.275279   7.466545
# Asset turnover                              1.117852   1.042208   0.847562
# Operating cash flow per share               7.532763   6.229346    4.64923
# Free cash flow per share                    6.872426   5.565624   4.228014
# Cash per share                              2.978793   3.750553   5.241031
# Payout ratio                                0.148703   0.152799   0.245267
# Operating cash flow sales ratio              0.30977   0.284399   0.293878
# Free cash flow operating cash flow ratio    0.912338   0.893452   0.909401
# Cash flow coverage ratios                    1.01734   0.834179    0.71751
# Short term coverage ratios                  5.786405    6.66355   5.859104
# Capital expenditure coverage ratio        -11.407452  -9.385476 -11.037625
# Dividend paid and capex coverage ratio     29.555045  30.762271  11.912877
# Dividend payout ratio                       0.148703   0.152799   0.245267
# Price book value ratio                      48.14034  38.892865   29.81827
# Price to book ratio                         48.14034  38.892865   29.81827
# Price to sales ratio                        6.186138   6.707591   7.097229
# Price earnings ratio                       24.441824  25.916254  33.935934
# Price to free cash flows ratio             21.888924  26.397759  26.556204
# Price to operating cash flows ratio        19.970097  23.585141  24.150233
# Price cash flow ratio                      19.970097  23.585141  24.150233
# Price earnings to growth ratio               2.88719   0.363486   3.170889
# Price sales ratio                           6.186138   6.707591   7.097229
# Dividend yield                              0.006084   0.005896   0.007227
# Enterprise value multiple                   19.42524  21.155006  26.152202
# Price fair value                            48.14034  38.892865   29.81827
#
# Fiscal Date Ending                              2019        2018
# Period                                            FY          FY
# Current ratio                               1.540126    1.123843
# Quick ratio                                 1.384447    0.986566
# Cash ratio                                  0.462022    0.221733
# Days of sales outstanding                  64.258765   67.332499
# Days of inventory outstanding               9.263639    8.817631
# Operating cycle                            73.522404    76.15013
# Days of payables outstanding              104.314077  124.570214
# Cash conversion cycle                     -30.791673  -48.420084
# Gross profit margin                         0.378178    0.383437
# Operating profit margin                      0.24572     0.26694
# Pretax profit margin                        0.252666    0.274489
# Net profit margin                           0.212381    0.224142
# Effective tax rate                          0.159438    0.183422
# Return on assets                             0.16323    0.162775
# Return on equity                            0.610645    0.555601
# Return on capital employed                  0.274616    0.284892
# Net income per EBT                          0.840562    0.816578
# Ebt per ebit                                1.028265     1.02828
# Ebit per revenue                             0.24572     0.26694
# Debt ratio                                  0.319178     0.31303
# Debt equity ratio                           1.194048    1.068467
# Long term debt to capitalization            0.503618    0.466617
# Total debt to capitalization                0.544221     0.51655
# Interest coverage                          17.877517   21.882099
# Cash flow to debt ratio                      0.64223     0.67638
# Company equity multiplier                   3.741004    3.413301
# Receivables turnover                        5.680159    5.420859
# Payables turnover                           3.499048    2.930074
# Inventory turnover                         39.401364   41.394338
# Fixed asset turnover                        6.960619    6.430249
# Asset turnover                              0.768572    0.726215
# Operating cash flow per share               3.756685    3.906565
# Free cash flow per share                    3.188508     3.23492
# Cash per share                              5.443948    3.344902
# Payout ratio                                 0.25552    0.230334
# Operating cash flow sales ratio              0.26671    0.291549
# Free cash flow operating cash flow ratio    0.848756    0.828073
# Cash flow coverage ratios                    0.64223     0.67638
# Short term coverage ratios                  4.272845    3.732119
# Capital expenditure coverage ratio         -6.611815    -5.81642
# Dividend paid and capex coverage ratio     19.147627  194.070175
# Dividend payout ratio                        0.25552    0.230334
# Price book value ratio                     11.167965   10.441038
# Price to book ratio                        11.167965   10.441038
# Price to sales ratio                        3.884196     4.21215
# Price earnings ratio                       18.288816   18.792325
# Price to free cash flows ratio             17.158496   17.447106
# Price to operating cash flows ratio         14.56337   14.447477
# Price cash flow ratio                       14.56337   14.447477
# Price earnings to growth ratio            -54.866447     0.64115
# Price sales ratio                           3.884196     4.21215
# Dividend yield                              0.013971    0.012257
# Enterprise value multiple                  13.988124   14.758938
# Price fair value                           11.167965   10.441038

# %%
ratios = openbb.stocks.fa.ratios(symbol = 'AAPL', limit = 20)
ratios.filter(like = 'Price earnings to growth ratio', axis = 0)
# Out:
# Fiscal Date Ending                 2022      2021      2020       2019  \
# Price earnings to growth ratio  2.88719  0.363486  3.170889 -54.866447
#
# Fiscal Date Ending                 2018
# Price earnings to growth ratio  0.64115

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
